# %% [markdown]
# <a href="https://colab.research.google.com/github/mcastiblancoa/AlgorithmsUN2024II/blob/main/lab5%5CLAB_ATQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desarrollo laboratorio Quantiacs
# ## Presentado por: Manuel Castiblanco

# %% [markdown]
# ##Gráfica

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Sharpe Ratio

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Gaussian Naive Bayes
#
# Escogí el algoritmo **Gaussian Naive Bayes** por su simplicidad, eficiencia, capacidad para manejar datos con una distribución normal, su facilidad de interpretación y su buen desempeño con conjuntos de datos pequeños. Esto lo hace una opción adecuada para problemas de clasificación donde la velocidad y la eficiencia son cruciales, como la predicción de movimientos de precios.

# %% [markdown]
# https://scikit-learn.org/stable/modules/naive_bayes.html

# %% [markdown]
# https://builtin.com/artificial-intelligence/gaussian-naive-bayes

# %% [markdown]
# ## Variable agregada

# %% [markdown]
# On Balance Volume (OBV) es un indicador de volumen que mide el flujo de volumen acumulado en relación con los cambios de precio. El concepto detrás de OBV es que los cambios en el volumen preceden los movimientos de precio, y por lo tanto, se puede utilizar para confirmar la dirección de una tendencia o detectar posibles señales de reversión.
#
# **¿Cómo funciona OBV?**
# - Si el precio de un activo cierra más alto que el cierre anterior, el volumen de ese día se acumula al OBV.
# - Si el precio cierra más bajo que el cierre anterior, el volumen se descarta.
# - Si el precio cierra sin cambios, el OBV permanece igual.
#
#
# **Interpretación:**
#
# OBV creciente: Si el OBV está subiendo, significa que el volumen de compra está superando al de venta, lo que generalmente indica que la tendencia alcista es fuerte.
#
#
# OBV decreciente: Si el OBV está cayendo, indica que el volumen de venta está superando al de compra, sugiriendo que la tendencia bajista es fuerte.
# Diversión entre OBV y precio: Si el precio está subiendo, pero el OBV no lo sigue, podría ser una señal de que la tendencia está perdiendo fuerza y una reversión podría estar cerca.

# %% [markdown]
# https://quantiacs.com/documentation/en/user_guide/technical_indicators.html

# %% [markdown]
# ##get_target_classes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# El class_negative fue agregado para representar de manera explícita los movimientos del mercado a la baja (más de una caída del 0.1%), lo que ayuda a crear un conjunto de clases más completo para predecir los movimientos de precio (subida, caída o movimiento neutro) en lugar de solo diferenciar entre subidas y movimientos pequeños

# %% [markdown]
# ## Comentario adicional

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Como comentario adicional, se puede observar cómo el cambiar la función **get_target_clases** afecta significativamente el valor final del Sharpe Ratio. Pasando de un valor de 0.2823 a uno de 0.5985
